# %% [markdown]
# <a href="https://colab.research.google.com/github/PsicoJazz/Ciencia-de-Dados/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importar Bíbliotecas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Series: observar lado esquerdo

# %%
s1 = pd.Series([1,2,-5,0])

# %%
s1
# Out:
# 0    1
# 1    2
# 2   -5
# 3    0
# dtype: int64

# %%
s1.values
# Out:
# array([ 1,  2, -5,  0])

# %%
s1.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# **Alterar índice**

# %%
s2 = pd.Series([1,2,-5,0], index = ['a','b','c','d'])

# %%
s2
# Out:
# a    1
# b    2
# c   -5
# d    0
# dtype: int64

# %%
s2.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
s2['a'] = 1000

# %%
s2
# Out:
# a    1000
# b       2
# c      -5
# d       0
# dtype: int64

# %%
s2.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %% [markdown]
# # Comparação

# %%
s2[s2>0]
# Out:
# a    1000
# b       2
# dtype: int64

# %% [markdown]
# # Algebra

# %%
s2*2
# Out:
# a    2000
# b       4
# c     -10
# d       0
# dtype: int64

# %%
s2.isnull()
# Out:
# a    False
# b    False
# c    False
# d    False
# dtype: bool

# %% [markdown]
# # Dataframe

# %%
dados = {'estado':['SP', 'MG', 'PR', 'SP', 'MG', 'PR'], 'ano':[2019, 2019, 2019, 2020, 2020, 2020], 'pop':[45.9, 21.2, 16.9, 46.6, 21.4, 17.3]}

# %%
df1 = pd.DataFrame(dados)

# %%
df1
# Out:
#   estado   ano   pop
# 0     SP  2019  45.9
# 1     MG  2019  21.2
# 2     PR  2019  16.9
# 3     SP  2020  46.6
# 4     MG  2020  21.4
# 5     PR  2020  17.3

# %% [markdown]
# Visualizar partes do DataFrame

# %%
df1.head(3)
# Out:
#   estado   ano   pop
# 0     SP  2019  45.9
# 1     MG  2019  21.2
# 2     PR  2019  16.9

# %%
df1.tail(2)
# Out:
#   estado   ano   pop
# 4     MG  2020  21.4
# 5     PR  2020  17.3

# %%
df1.sample(2)
# Out:
#   estado   ano   pop
# 4     MG  2020  21.4
# 3     SP  2020  46.6

# %% [markdown]
# # Novo DataFrame a partir do anterior

# %% [markdown]
# Mudar ordem indice

# %%
df2 = pd.DataFrame(dados, columns=['ano', 'pop', 'estado'])

# %%
df2
# Out:
#     ano   pop estado
# 0  2019  45.9     SP
# 1  2019  21.2     MG
# 2  2019  16.9     PR
# 3  2020  46.6     SP
# 4  2020  21.4     MG
# 5  2020  17.3     PR

# %% [markdown]
# # Observar no DF

# %%
df2['estado']
# Out:
# 0    SP
# 1    MG
# 2    PR
# 3    SP
# 4    MG
# 5    PR
# Name: estado, dtype: object

# %%
df2['ano']
# Out:
# 0    2019
# 1    2019
# 2    2019
# 3    2020
# 4    2020
# 5    2020
# Name: ano, dtype: int64

# %%
df2.dtypes
# Out:
# ano         int64
# pop       float64
# estado     object
# dtype: object

# %% [markdown]
# # Atribuir valores

# %%
df2 ['estimativa']=50

# %%
df2
# Out:
#     ano   pop estado  estimativa
# 0  2019  45.9     SP           0
# 1  2019  21.2     MG           1
# 2  2019  16.9     PR           2
# 3  2020  46.6     SP           3
# 4  2020  21.4     MG           4
# 5  2020  17.3     PR           5

# %%
df2 ['estimativa'] = np.arange(6)

# %%
df2
# Out:
#     ano   pop estado  estimativa
# 0  2019  45.9     SP           0
# 1  2019  21.2     MG           1
# 2  2019  16.9     PR           2
# 3  2020  46.6     SP           3
# 4  2020  21.4     MG           4
# 5  2020  17.3     PR           5

# %% [markdown]
# Recortar coluna

# %%
df3 = df2['ano']

# %%
df3
# Out:
# 0    2019
# 1    2019
# 2    2019
# 3    2020
# 4    2020
# 5    2020
# Name: ano, dtype: int64

# %%
df2 ['Não Paraná'] = df2['estado'] != 'PR'

# %%
df2
# Out:
#     ano   pop estado  estimativa  Não Paraná
# 0  2019  45.9     SP           0        True
# 1  2019  21.2     MG           1        True
# 2  2019  16.9     PR           2       False
# 3  2020  46.6     SP           3        True
# 4  2020  21.4     MG           4        True
# 5  2020  17.3     PR           5       False

# %% [markdown]
# # Excluir coluna

# %%
del df2 ['Não Paraná']

# %%
df2
# Out:
#     ano   pop estado  estimativa
# 0  2019  45.9     SP           0
# 1  2019  21.2     MG           1
# 2  2019  16.9     PR           2
# 3  2020  46.6     SP           3
# 4  2020  21.4     MG           4
# 5  2020  17.3     PR           5

# %% [markdown]
# # Mais do DF

# %% [markdown]
# Tamanho DF

# %%
df2.shape
# Out:
# (6, 4)

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df2.columns
# Out:
# Index(['ano', 'pop', 'estado', 'estimativa'], dtype='object')

# %% [markdown]
# Ver se ha elementos nulos

# %%
df2.count()
# Out:
# ano           6
# pop           6
# estado        6
# estimativa    6
# dtype: int64

# %% [markdown]
# # Alterar informações das colunas

# %%
df2.columns = ['Ano', 'estados', 'População', 'Estimativa']

# %%
df2
# Out:
#     Ano  estados População  Estimativa
# 0  2019     45.9        SP           0
# 1  2019     21.2        MG           1
# 2  2019     16.9        PR           2
# 3  2020     46.6        SP           3
# 4  2020     21.4        MG           4
# 5  2020     17.3        PR           5

# %% [markdown]
# # Analisar DF

# %%
df2.describe(include = 'all')
# Out:
#                 Ano    estados População  Estimativa
# count      6.000000   6.000000         6    6.000000
# unique          NaN        NaN         3         NaN
# top             NaN        NaN        SP         NaN
# freq            NaN        NaN         2         NaN
# mean    2019.500000  28.216667       NaN    2.500000
# std        0.547723  14.096725       NaN    1.870829
# min     2019.000000  16.900000       NaN    0.000000
# 25%     2019.000000  18.275000       NaN    1.250000
# 50%     2019.500000  21.300000       NaN    2.500000
# 75%     2020.000000  39.775000       NaN    3.750000
# max     2020.000000  46.600000       NaN    5.000000

# %% [markdown]
# # Alterar valores e consultar dados

# %%
df2 ['Ano']= df2['Ano']+2

# %%
df2
# Out:
#     Ano  estados População  Estimativa
# 0  2021     45.9        SP           0
# 1  2021     21.2        MG           1
# 2  2021     16.9        PR           2
# 3  2022     46.6        SP           3
# 4  2022     21.4        MG           4
# 5  2022     17.3        PR           5

# %%
df2[df2['Ano']>2021]
# Out:
#     Ano  estados População  Estimativa
# 3  2022     46.6        SP           3
# 4  2022     21.4        MG           4
# 5  2022     17.3        PR           5

# %%
df4=df2[df2['Ano']>2021]

# %%
df4
# Out:
#     Ano  estados População  Estimativa
# 3  2022     46.6        SP           3
# 4  2022     21.4        MG           4
# 5  2022     17.3        PR           5

# %% [markdown]
# # Excluir colunas

# %%
df4.drop('Ano', axis='columns')
# Out:
#    estados População  Estimativa
# 3     46.6        SP           3
# 4     21.4        MG           4
# 5     17.3        PR           5

# %%
df2
# Out:
#     Ano  estados População  Estimativa
# 0  2021     45.9        SP           0
# 1  2021     21.2        MG           1
# 2  2021     16.9        PR           2
# 3  2022     46.6        SP           3
# 4  2022     21.4        MG           4
# 5  2022     17.3        PR           5

# %% [markdown]
# Nesse caso nao mostra resultado, mas exclui efetivamente a coluna

# %%
df2.drop('Ano', axis='columns', inplace= True)

# %%
df2
# Out:
#    estados População  Estimativa
# 0     45.9        SP           0
# 1     21.2        MG           1
# 2     16.9        PR           2
# 3     46.6        SP           3
# 4     21.4        MG           4
# 5     17.3        PR           5

# %% [markdown]
# # Excluir linha

# %%
df2.drop([0,1])
# Out:
#    estados População  Estimativa
# 2     16.9        PR           2
# 3     46.6        SP           3
# 4     21.4        MG           4
# 5     17.3        PR           5

# %% [markdown]
# Propagação na exclusao definitiva

# %%
dflinhas = df2

# %%
dflinhas.drop([0,1], inplace=True)

# %%
dflinhas
# Out:
#    estados População  Estimativa
# 2     16.9        PR           2
# 3     46.6        SP           3
# 4     21.4        MG           4
# 5     17.3        PR           5

# %% [markdown]
# # Ver dados de linha

# %%
df2.iloc[0]
# Out:
# estados       16.9
# População       PR
# Estimativa       2
# Name: 2, dtype: object

# %%
df2.iloc[1:3]
# Out:
#    estados População  Estimativa
# 3     46.6        SP           3
# 4     21.4        MG           4

# %% [markdown]
# selecionar colunas

# %%
df2.iloc[1:3,[1,2]]
# Out:
#   População  Estimativa
# 3        SP           3
# 4        MG           4
